# %%
import pandas as pd

df = pd.read_parquet("/share/galaxy/thanyathon/candrug_pipeline/full_dataset/data/staging/s07b_llm_clean/pediatric_drugs_llm_cleaned_full_data.parquet")
df
# Out:
#                                    medicinal_product  \
# 0                                            INTUNIV
# 1                                           CANNABIS
# 2                                  CELESTENE 4MG/1ML
# 3                                     PHLOROGLUCINOL
# 4                                          EPIDIOLEX
# ...                                              ...
# 47734                                     ALCORTIN A
# 47735                       ASPIRIN CHEWABLE TABLETS
# 47736  CROMOLYN                           /00082101/
# 47737                             NEOMYCIN-POLYMYXIN
# 47738                                        LIPARIN
#
#                        basename         ingredients  salt strength  \
# 0                       INTUNIV                None  None     None
# 1                      CANNABIS            CANNABIS  None     None
# 2                     CELESTENE                None  None      4MG
# ...

# %%
df['basename'].nunique()
# Out:
# 33348

# %%
df['ingredients'].nunique()
# Out:
# 11923
