# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../notebook/output/csv/ped_adult_intersection.csv")
df
# Out:
#              cohort  safetyreportid    rxcui       reaction_meddrapt  \
# 0         Pediatric         9911480   191831                 Pyrexia
# 1         Pediatric        15429502     2683            Hypokalaemia
# 2         Pediatric        21735875   224911            Pancytopenia
# 3         Pediatric        26063044    10180  Hypogammaglobulinaemia
# 4         Pediatric        12961531    11198                 Pyrexia
# ...             ...             ...      ...                     ...
# 11995731      Adult        25286532  2196895            Inflammation
# 11995732      Adult        18750057  2196895        Immunodeficiency
# 11995733      Adult        23574753      161                    Coma
# 11995734      Adult        19828435      161              Depression
# 11995735      Adult        17974542   358258                   Death
#
#                         medicinal_product  \
# 0                              INFLIXIMAB
# 1                             COLCHICINE.
# ...

# %%
df.shape
# Out:
# (11995736, 6)

# %%
df.columns.tolist()
# Out:
# ['cohort',
#  'safetyreportid',
#  'rxcui',
#  'reaction_meddrapt',
#  'medicinal_product',
#  'ingredient']

# %%
df.isnull().sum()
# Out:
# cohort               0
# safetyreportid       0
# rxcui                0
# reaction_meddrapt    0
# medicinal_product    0
# ingredient           0
# dtype: int64
